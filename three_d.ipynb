# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from itertools import product, combinations

# %%
r = 20
fig = plt.figure(figsize=(15,15))

u = np.linspace(0, np.pi, 20)
v = np.linspace(0, 2 * np.pi, 20)

x = r * np.outer(np.cos(u), np.sin(v))
y = r * np.outer(np.sin(u), np.sin(v))
z = r * np.outer(np.ones_like(np.sin(u)),np.cos(v))

ax = plt.axes(projection='3d')
ax.plot_wireframe(x, y, z)

r = 20/np.sqrt(3)
r = [-r, r]
for s, e in combinations(np.array(list(product(r, r, r))), 2):
   if np.sum(np.abs(s-e)) == r[1]-r[0]:
      ax.plot3D(*zip(s, e), color="red", linewidth=5,)
      ax.scatter3D(*zip(s, e))

plt.show()
print('x=',x,'\ny=',y,'\nz=',z)
# Out:
# x= [[ 0.00000000e+00  6.49398938e+00  1.22842543e+01  1.67433296e+01
#    1.93880053e+01  1.99316899e+01  1.83154665e+01  1.47144782e+01
#    9.51894786e+00  3.29189181e+00 -3.29189181e+00 -9.51894786e+00
#   -1.47144782e+01 -1.83154665e+01 -1.99316899e+01 -1.93880053e+01
#   -1.67433296e+01 -1.22842543e+01 -6.49398938e+00 -4.89858720e-15]
#  [ 0.00000000e+00  6.40541983e+00  1.21167130e+01  1.65149724e+01
#    1.91235782e+01  1.96598476e+01  1.80656674e+01  1.45137919e+01
#    9.38912182e+00  3.24699469e+00 -3.24699469e+00 -9.38912182e+00
#   -1.45137919e+01 -1.80656674e+01 -1.96598476e+01 -1.91235782e+01
#   -1.65149724e+01 -1.21167130e+01 -6.40541983e+00 -4.83177685e-15]
#  [ 0.00000000e+00  6.14212713e+00  1.16186595e+01  1.58361298e+01
#    1.83375097e+01  1.88517359e+01  1.73230840e+01  1.39172072e+01
#    9.00318501e+00  3.11352803e+00 -3.11352803e+00 -9.00318501e+00
#   -1.39172072e+01 -1.73230840e+01 -1.88517359e+01 -1.83375097e+01
# ...

# %%
r = 20
fig = plt.figure(figsize=(15,15))

u = np.linspace(0, np.pi, 20)
v = np.linspace(0, 2 * np.pi, 20)

x = r * np.outer(np.cos(u), np.sin(v))
y = r * np.outer(np.sin(u), np.sin(v))
z = r * np.outer(np.ones_like(np.sin(u)),np.cos(v))

ax = plt.axes(projection='3d')
ax.plot_wireframe(x, y, z)

r = [-20, 20]
for s, e in combinations(np.array(list(product(r, r, r))), 2):
   if np.sum(np.abs(s-e)) == r[1]-r[0]:
      ax.plot3D(*zip(s, e), color="red", linewidth=5,)
      ax.scatter3D(*zip(s, e))

plt.show()
print('x=',x,'\ny=',y,'\nz=',z)
# Out:
# x= [[ 0.00000000e+00  6.49398938e+00  1.22842543e+01  1.67433296e+01
#    1.93880053e+01  1.99316899e+01  1.83154665e+01  1.47144782e+01
#    9.51894786e+00  3.29189181e+00 -3.29189181e+00 -9.51894786e+00
#   -1.47144782e+01 -1.83154665e+01 -1.99316899e+01 -1.93880053e+01
#   -1.67433296e+01 -1.22842543e+01 -6.49398938e+00 -4.89858720e-15]
#  [ 0.00000000e+00  6.40541983e+00  1.21167130e+01  1.65149724e+01
#    1.91235782e+01  1.96598476e+01  1.80656674e+01  1.45137919e+01
#    9.38912182e+00  3.24699469e+00 -3.24699469e+00 -9.38912182e+00
#   -1.45137919e+01 -1.80656674e+01 -1.96598476e+01 -1.91235782e+01
#   -1.65149724e+01 -1.21167130e+01 -6.40541983e+00 -4.83177685e-15]
#  [ 0.00000000e+00  6.14212713e+00  1.16186595e+01  1.58361298e+01
#    1.83375097e+01  1.88517359e+01  1.73230840e+01  1.39172072e+01
#    9.00318501e+00  3.11352803e+00 -3.11352803e+00 -9.00318501e+00
#   -1.39172072e+01 -1.73230840e+01 -1.88517359e+01 -1.83375097e+01
# ...
