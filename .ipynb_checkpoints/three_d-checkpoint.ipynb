# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from itertools import product, combinations

# %%
r = 20
fig = plt.figure(figsize=(15,15))

u = np.linspace(0, np.pi, 150)
v = np.linspace(0, 2 * np.pi, 150)

x = r * np.outer(np.cos(u), np.sin(v))
y = r * np.outer(np.sin(u), np.sin(v))
z = r * np.outer(np.ones_like(np.sin(u)),np.cos(v))

ax = plt.axes(projection='3d')
ax.plot_wireframe(x, y, z)

r = 20/np.sqrt(3)
r = [-r, r]
for s, e in combinations(np.array(list(product(r, r, r))), 2):
   if np.sum(np.abs(s-e)) == r[1]-r[0]:
      ax.plot3D(*zip(s, e), color="red", linewidth=5,)
      ax.scatter3D(*zip(s, e))

plt.show()
print('x=',x,'\ny=',y,'\nz=',z)
# Out:
# x= [[ 0.00000000e+00  8.43130647e-01  1.68476224e+00 ... -1.68476224e+00
#   -8.43130647e-01 -4.89858720e-15]
#  [ 0.00000000e+00  8.42943244e-01  1.68438777e+00 ... -1.68438777e+00
#   -8.42943244e-01 -4.89749839e-15]
#  [ 0.00000000e+00  8.42381119e-01  1.68326451e+00 ... -1.68326451e+00
#   -8.42381119e-01 -4.89423244e-15]
#  ...
#  [-0.00000000e+00 -8.42381119e-01 -1.68326451e+00 ...  1.68326451e+00
#    8.42381119e-01  4.89423244e-15]
#  [-0.00000000e+00 -8.42943244e-01 -1.68438777e+00 ...  1.68438777e+00
#    8.42943244e-01  4.89749839e-15]
#  [-0.00000000e+00 -8.43130647e-01 -1.68476224e+00 ...  1.68476224e+00
#    8.43130647e-01  4.89858720e-15]]
# y= [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -0.00000000e+00
#   -0.00000000e+00 -0.00000000e+00]
#  [ 0.00000000e+00  1.77756832e-02  3.55197619e-02 ... -3.55197619e-02
#   -1.77756832e-02 -1.03276680e-16]
#  [ 0.00000000e+00  3.55434644e-02  7.10237338e-02 ... -7.10237338e-02
#   -3.55434644e-02 -2.06507450e-16]
#  ...
#  [ 0.00000000e+00  3.55434644e-02  7.10237338e-02 ... -7.10237338e-02
#   -3.55434644e-02 -2.06507450e-16]
#  [ 0.00000000e+00  1.77756832e-02  3.55197619e-02 ... -3.55197619e-02
#   -1.77756832e-02 -1.03276680e-16]
#  [ 0.00000000e+00  1.03253725e-16  2.06323868e-16 ... -2.06323868e-16
#   -1.03253725e-16 -5.99903913e-31]]
# z= [[20.         19.98222036 19.92891307 ... 19.92891307 19.98222036
#   20.        ]
#  [20.         19.98222036 19.92891307 ... 19.92891307 19.98222036
#   20.        ]
#  [20.         19.98222036 19.92891307 ... 19.92891307 19.98222036
#   20.        ]
#  ...
#  [20.         19.98222036 19.92891307 ... 19.92891307 19.98222036
#   20.        ]
#  [20.         19.98222036 19.92891307 ... 19.92891307 19.98222036
#   20.        ]
#  [20.         19.98222036 19.92891307 ... 19.92891307 19.98222036
#   20.        ]]

# %%
r = 20
fig = plt.figure(figsize=(15,15))

u = np.linspace(0, np.pi, 120)
v = np.linspace(0, 2 * np.pi, 120)

x = r * np.outer(np.cos(u), np.sin(v))
y = r * np.outer(np.sin(u), np.sin(v))
z = r * np.outer(np.ones_like(np.sin(u)),np.cos(v))

ax = plt.axes(projection='3d')
ax.plot_wireframe(x, y, z)

r = [-20, 20]
for s, e in combinations(np.array(list(product(r, r, r))), 2):
   if np.sum(np.abs(s-e)) == r[1]-r[0]:
      ax.plot3D(*zip(s, e), color="red", linewidth=5,)
      ax.scatter3D(*zip(s, e))

plt.show()
print('x=',x,'\ny=',y,'\nz=',z)
# Out:
# x= [[ 0.00000000e+00  1.05550694e+00  2.10807200e+00 ... -2.10807200e+00
#   -1.05550694e+00 -4.89858720e-15]
#  [ 0.00000000e+00  1.05513914e+00  2.10733742e+00 ... -2.10733742e+00
#   -1.05513914e+00 -4.89688024e-15]
#  [ 0.00000000e+00  1.05403600e+00  2.10513421e+00 ... -2.10513421e+00
#   -1.05403600e+00 -4.89176058e-15]
#  ...
#  [-0.00000000e+00 -1.05403600e+00 -2.10513421e+00 ...  2.10513421e+00
#    1.05403600e+00  4.89176058e-15]
#  [-0.00000000e+00 -1.05513914e+00 -2.10733742e+00 ...  2.10733742e+00
#    1.05513914e+00  4.89688024e-15]
#  [-0.00000000e+00 -1.05550694e+00 -2.10807200e+00 ...  2.10807200e+00
#    1.05550694e+00  4.89858720e-15]]
# y= [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -0.00000000e+00
#   -0.00000000e+00 -0.00000000e+00]
#  [ 0.00000000e+00  2.78620814e-02  5.56465062e-02 ... -5.56465062e-02
#   -2.78620814e-02 -1.29307378e-16]
#  [ 0.00000000e+00  5.57047453e-02  1.11254231e-01 ... -1.11254231e-01
#   -5.57047453e-02 -2.58524640e-16]
#  ...
#  [ 0.00000000e+00  5.57047453e-02  1.11254231e-01 ... -1.11254231e-01
#   -5.57047453e-02 -2.58524640e-16]
#  [ 0.00000000e+00  2.78620814e-02  5.56465062e-02 ... -5.56465062e-02
#   -2.78620814e-02 -1.29307378e-16]
#  [ 0.00000000e+00  1.29262320e-16  2.58164362e-16 ... -2.58164362e-16
#   -1.29262320e-16 -5.99903913e-31]]
# z= [[20.         19.97212821 19.88859051 ... 19.88859051 19.97212821
#   20.        ]
#  [20.         19.97212821 19.88859051 ... 19.88859051 19.97212821
#   20.        ]
#  [20.         19.97212821 19.88859051 ... 19.88859051 19.97212821
#   20.        ]
#  ...
#  [20.         19.97212821 19.88859051 ... 19.88859051 19.97212821
#   20.        ]
#  [20.         19.97212821 19.88859051 ... 19.88859051 19.97212821
#   20.        ]
#  [20.         19.97212821 19.88859051 ... 19.88859051 19.97212821
#   20.        ]]
